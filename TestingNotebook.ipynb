# %%
import matplotlib.pyplot as plt
import numpy as np
import data_visualization as dv

# %%
dv.get_healthy_icon()
dv.get_elderly_icon()
dv.get_foot_icon()
dv.get_walking_icon()
dv.get_open_hand_icon()
dv.get_hand_icon(color = "#FF0000")
dv.get_sight_icon()
dv.get_reward_icon()
dv.get_punishment_icon(color = "#FF0000")
# Out:
# <PIL.Image.Image image mode=RGBA size=825x560>

# %%
dv.get_punishment_icon()
# Out:
# <PIL.Image.Image image mode=RGBA size=825x560>
